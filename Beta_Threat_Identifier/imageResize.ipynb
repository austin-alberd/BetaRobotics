# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread(r"C:\Users\austi\Desktop\newBGitem.jpg", cv.IMREAD_UNCHANGED)
nImg= cv.resize(img,(32,32))
plt.imshow(nImg)

cv.imwrite(r"C:\Users\austi\Desktop\newBGCircle.jpg",nImg)
# Out:
# True
